# %% [markdown]
# # **Advanced Pandas Data Frame**
# by Farah
#
# 1. Indexing data frame
# 2. Menghapus variabel atau kolom
# 3. Joining data frame
# 4. Concatenate dan append data frame
# 5. Fungsi Lambda
# 6. Pivot table data frame

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load The Data

# %%
# load data

data = pd.read_csv("https://raw.githubusercontent.com/densaiko/data_science_learning/main/dataset/insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## **1. Indexing Data Frame**

# %% [markdown]
# ### Reset index

# %%
sample = data.sample(n=35)
sample.head()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 287    63  female  26.220         0     no  northwest  14256.19280
# 413    25    male  23.900         5     no  southwest   5080.09600
# 1129   19  female  18.600         0     no  southwest   1728.89700
# 1044   55    male  35.245         1     no  northeast  11394.06555
# 308    58    male  34.865         0     no  northeast  11944.59435

# %%
reset = sample.reset_index(drop=True)
reset.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   63  female  26.220         0     no  northwest  14256.19280
# 1   25    male  23.900         5     no  southwest   5080.09600
# 2   19  female  18.600         0     no  southwest   1728.89700
# 3   55    male  35.245         1     no  northeast  11394.06555
# 4   58    male  34.865         0     no  northeast  11944.59435

# %% [markdown]
# ### Membuat index baru dari suatu kolom

# %%
reset.set_index("age").head()
# Out:
#         sex     bmi  children smoker     region      charges
# age
# 63   female  26.220         0     no  northwest  14256.19280
# 25     male  23.900         5     no  southwest   5080.09600
# 19   female  18.600         0     no  southwest   1728.89700
# 55     male  35.245         1     no  northeast  11394.06555
# 58     male  34.865         0     no  northeast  11944.59435

# %% [markdown]
# ## **2. Menghapus Variabel atau Kolom**
#
# Pandas mempunyai fungsi untuk menghapus kolom yang tidak diinginkan. Tujuan dari menghapus kolom ini diantaranya adalah:
# - Untuk memilih kolom yang akan dianalisa lebih lanjut
# - Untuk memilih kolom yang akan digunakan dalam pembuatan model ML

# %%
data.drop(["children","sex"], axis=1).head()
# Out:
#    age     bmi smoker     region      charges
# 0   19  27.900    yes  southwest  16884.92400
# 1   18  33.770     no  southeast   1725.55230
# 2   28  33.000     no  southeast   4449.46200
# 3   33  22.705     no  northwest  21984.47061
# 4   32  28.880     no  northwest   3866.85520

# %% [markdown]
# ## **3. Joining Data Frame**
#
# Selain menggunakan `'merge`, Pandas juga bisa menggabungkan data frame menggunakan fungsi `join`
#
# `join` digunakan untuk menggabungkan data berdasarkan index sedangkan `merge` digunakan untuk menggabungkan data menggunakan kolom

# %%
data_1 = data.iloc[3:7,2:5]
data_1
# Out:
#       bmi  children smoker
# 3  22.705         0     no
# 4  28.880         0     no
# 5  25.740         0     no
# 6  33.440         1     no

# %%
data_2 = data.loc[3:10,["bmi","region","charges"]]
data_2
# Out:
#        bmi     region      charges
# 3   22.705  northwest  21984.47061
# 4   28.880  northwest   3866.85520
# 5   25.740  southeast   3756.62160
# 6   33.440  southeast   8240.58960
# 7   27.740  northwest   7281.50560
# 8   29.830  northeast   6406.41070
# 9   25.840  northwest  28923.13692
# 10  26.220  northeast   2721.32080

# %%
data_1.join(data_2, lsuffix='_first', rsuffix='_second')
# Out:
#    bmi_first  children smoker  bmi_second     region      charges
# 3     22.705         0     no      22.705  northwest  21984.47061
# 4     28.880         0     no      28.880  northwest   3866.85520
# 5     25.740         0     no      25.740  southeast   3756.62160
# 6     33.440         1     no      33.440  southeast   8240.58960

# %%
data_2.join(data_1, lsuffix='_first', rsuffix='_second')
# Out:
#     bmi_first     region      charges  bmi_second  children smoker
# 3      22.705  northwest  21984.47061      22.705       0.0     no
# 4      28.880  northwest   3866.85520      28.880       0.0     no
# 5      25.740  southeast   3756.62160      25.740       0.0     no
# 6      33.440  southeast   8240.58960      33.440       1.0     no
# 7      27.740  northwest   7281.50560         NaN       NaN    NaN
# 8      29.830  northeast   6406.41070         NaN       NaN    NaN
# 9      25.840  northwest  28923.13692         NaN       NaN    NaN
# 10     26.220  northeast   2721.32080         NaN       NaN    NaN

# %% [markdown]
# ## **4. Concatenate & Append Dataframe**

# %% [markdown]
# ### Concatenate dataframe
#
# Menggabungkan data frame berdasarkan axis-nya, baik axis x (horizontal) atau axis y (vertikal)

# %%
# Horizontal

pd.concat([data_1, data_2], axis=1)
# Out:
#        bmi  children smoker     bmi     region      charges
# 3   22.705       0.0     no  22.705  northwest  21984.47061
# 4   28.880       0.0     no  28.880  northwest   3866.85520
# 5   25.740       0.0     no  25.740  southeast   3756.62160
# 6   33.440       1.0     no  33.440  southeast   8240.58960
# 7      NaN       NaN    NaN  27.740  northwest   7281.50560
# 8      NaN       NaN    NaN  29.830  northeast   6406.41070
# 9      NaN       NaN    NaN  25.840  northwest  28923.13692
# 10     NaN       NaN    NaN  26.220  northeast   2721.32080

# %%
# Vertikal

pd.concat([data_1, data_2], axis=0)
# Out:
#        bmi  children smoker     region      charges
# 3   22.705       0.0     no        NaN          NaN
# 4   28.880       0.0     no        NaN          NaN
# 5   25.740       0.0     no        NaN          NaN
# 6   33.440       1.0     no        NaN          NaN
# 3   22.705       NaN    NaN  northwest  21984.47061
# 4   28.880       NaN    NaN  northwest   3866.85520
# 5   25.740       NaN    NaN  southeast   3756.62160
# 6   33.440       NaN    NaN  southeast   8240.58960
# 7   27.740       NaN    NaN  northwest   7281.50560
# 8   29.830       NaN    NaN  northeast   6406.41070
# 9   25.840       NaN    NaN  northwest  28923.13692
# 10  26.220       NaN    NaN  northeast   2721.32080

# %% [markdown]
# ### Append
#
# Append dapat dilakukan jika terdapat nama kolom yang sama pada kedua data set yang ingin digabungkan

# %%
data_1.append(data_2)
# Out:
#        bmi  children smoker     region      charges
# 3   22.705       0.0     no        NaN          NaN
# 4   28.880       0.0     no        NaN          NaN
# 5   25.740       0.0     no        NaN          NaN
# 6   33.440       1.0     no        NaN          NaN
# 3   22.705       NaN    NaN  northwest  21984.47061
# 4   28.880       NaN    NaN  northwest   3866.85520
# 5   25.740       NaN    NaN  southeast   3756.62160
# 6   33.440       NaN    NaN  southeast   8240.58960
# 7   27.740       NaN    NaN  northwest   7281.50560
# 8   29.830       NaN    NaN  northeast   6406.41070
# 9   25.840       NaN    NaN  northwest  28923.13692
# 10  26.220       NaN    NaN  northeast   2721.32080

# %% [markdown]
# ## **5. Fungsi Lambda**
#
# Fungsi Lambda digunakan untuk mempersingkat syntax python

# %%
# Mengelompokkan data BMI menggunakan Fungsi Lambda

data['bmi_category'] = data['bmi'].apply(lambda x: 'High BMI' if x >= 50 else ('Medium BMI' if x >=30 and x<50 else "Low BMI"))
data.sample(n=10)
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 1029   37  female  17.290         2     no  northeast   6877.98010
# 365    49  female  30.780         1     no  northeast   9778.34720
# 240    23  female  36.670         2    yes  northeast  38511.62830
# 780    30    male  24.400         3    yes  southwest  18259.21600
# 574    57  female  34.295         2     no  northeast  13224.05705
# 581    19    male  30.590         0     no  northwest   1639.56310
# 1237   58  female  28.215         0     no  northwest  12224.35085
# 377    24    male  40.150         0    yes  southeast  38126.24650
# 1136   44  female  25.000         1     no  southwest   7623.51800
# 555    28    male  23.800         2     no  southwest   3847.67400
#
#      bmi_category
# 1029      Low BMI
# 365    Medium BMI
# 240    Medium BMI
# 780       Low BMI
# 574    Medium BMI
# 581    Medium BMI
# 1237      Low BMI
# 377    Medium BMI
# 1136      Low BMI
# 555       Low BMI

# %%
# Membuat values di kolom sex, region dan bmi_category menjadi huruf kapital semua

data.loc[:,["sex", "region", "bmi_category"]].apply(lambda x: x.str.upper(),axis=1)
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges bmi_category
# 0   19  FEMALE  27.900         0    yes  SOUTHWEST  16884.92400      LOW BMI
# 1   18    MALE  33.770         1     no  SOUTHEAST   1725.55230   MEDIUM BMI
# 2   28    MALE  33.000         3     no  SOUTHEAST   4449.46200   MEDIUM BMI
# 3   33    MALE  22.705         0     no  NORTHWEST  21984.47061      LOW BMI
# 4   32    MALE  28.880         0     no  NORTHWEST   3866.85520      LOW BMI

# %% [markdown]
# ## **6. Pivot Table**
#
# Pivot table memberikan informasi berupa agregasi suatu data dengan melampirkan isi data pada nama kolom tertentu

# %%
pd.pivot_table(data, values="bmi", index=["sex","smoker"], columns="region", 
               aggfunc=np.max)
# Out:
# region         NORTHEAST  NORTHWEST  SOUTHEAST  SOUTHWEST
# sex    smoker
# FEMALE no         48.070     42.940      46.75       46.7
#        yes        42.750     38.950      47.41       47.6
# MALE   no         42.655     41.325      53.13       45.9
#        yes        41.895     40.565      52.58       39.9

# %%
pd.pivot_table(data, values=["bmi"], index=['bmi_category'], aggfunc={'bmi':[min, max, np.mean]})
# Out:
#                  bmi
#                  max       mean    min
# bmi_category
# HIGH BMI      53.130  52.030000  50.38
# LOW BMI       29.925  25.506426  15.96
# MEDIUM BMI    49.060  35.194574  30.00
